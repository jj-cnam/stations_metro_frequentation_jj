# %% [markdown]
# ---
# title: Exploration préparatoire des données et génération du fichier de données traitées
# ---
#
# *(Les fichiers téléchargés sont stockés ici :
#
# - https://minio.lab.sspcloud.fr/jacquemmoz/partage/validations-reseau-ferre-nombre-validations-par-jour-1er-trimestre.xlsx
# - https://minio.lab.sspcloud.fr/jacquemmoz/partage/validations-reseau-ferre-nombre-validations-par-jour-2eme-trimestre.xlsx
# - https://minio.lab.sspcloud.fr/jacquemmoz/partage/validations-reseau-ferre-nombre-validations-par-jour-3eme-trimestre.xlsx
# - https://minio.lab.sspcloud.fr/jacquemmoz/partage/validations-reseau-ferre-nombre-validations-par-jour-4eme-trimestre.xlsx
#
# )*

# %%
import pandas as pd
from numpy import datetime64, timedelta64

# %%
# Les fichiers partagés sur le service S3 d'Onyxia ont donc une URL de la forme :
fichier = "https://minio.lab.sspcloud.fr/jacquemmoz/partage/validations-reseau-ferre-nombre-validations-par-jour-{}-trimestre.xlsx"

# %% [markdown]
# # Examen des fichiers
#
# ## Premier fichier

# %%
# durée : environ 1 min
donnees1 = pd.read_excel(fichier.format("1er"))

# %%
donnees1.head()
# Out:
#          jour  code_stif_trns code_stif_res code_stif_arret  libelle_arret  \
# 0  2025-03-07             100           110             487      MADELEINE
# 1  2025-03-07             100           110              49   BARBES-ROCH.
# 2  2025-03-07             100           110          490763  S. GAINSBOURG
# 3  2025-03-07             100           110          490763  S. GAINSBOURG
# 4  2025-03-07             100           110          490763  S. GAINSBOURG
#
#       ida               categorie_titre  nb_vald
# 0   71324               Forfaits courts     3387
# 1   71426                 Autres titres      478
# 2  490779  Contrat Solidarité Transport      781
# 3  490779                Forfait Navigo     2880
# 4  490779                     Imagine R     1158

# %%
donnees1.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 469371  2025-03-01             800           853             485
# 469372  2025-03-01             800           853             536
# 469373  2025-03-01             800           853             536
# 469374  2025-03-01             800           853             568
# 469375  2025-03-01             800           853             568
#
#        libelle_arret    ida  categorie_titre  nb_vald
# 469371     LUZARCHES  67177   Forfait Navigo       47
# 469372        MERIEL  67065        Amethyste        2
# 469373        MERIEL  67065        Imagine R       50
# 469374     MONTSOULT  67000   Forfait Navigo      286
# 469375     MONTSOULT  67000  Forfaits courts       57

# %%
donnees1.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 409073  2025-02-01             800           854              58
# 237864  2025-02-27             800           853             249
# 53104   2025-02-05             100           110             373
# 10093   2025-01-20             100           110             300
# 22341   2025-03-16             800           852             303
# 350495  2025-03-16             810           801             594
# 419832  2025-01-14             100           110             898
# 51646   2025-02-03             800           854            1208
# 85442   2025-01-13             800           803             402
# 413410  2025-01-04             100           110             855
#
#           libelle_arret    ida               categorie_titre  nb_vald
# 409073            BECON  72124                     Imagine R      976
# 237864           ECOUEN  66533               Forfaits courts      166
# 53104            JAURES  71940                    NON DEFINI      133
# 10093          GALLIENI  71817                     Imagine R     1929
# 22341       GARANCIERES  64025  Contrat Solidarité Transport       12
# 350495   NOGENT-S-MARNE  71590  Contrat Solidarité Transport      484
# 419832     VILLEJ.P.V.C  70248                Forfait Navigo     4354
# 51646     MASSY PAL T12  63244                Forfait Navigo     3406
# 85442   NORVILLE ST GER  60115  Contrat Solidarité Transport       52
# 413410          TOLBIAC  71001                    NON DEFINI       42

# %%
donnees1.dtypes
# Out:
# jour               object
# code_stif_trns      int64
# code_stif_res      object
# code_stif_arret    object
# libelle_arret      object
# ida                 int64
# categorie_titre    object
# nb_vald             int64
# dtype: object

# %% [markdown]
# > On voit d'ores et déjà qu'il faudra recoder la colonne 'jour' pour la transformer en type date.
# La colonne nb_val est bien un entier.
# Les autres colonnes seront utilisables telles quelles : soit on les utilisera comme chaînes de caractères, soit uniquement pour un premier tri des données avant suppression.

# %% [markdown]
# ## Deuxième fichier

# %%
donnees2 = pd.read_excel(fichier.format("2eme"))

# %%
donnees2.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 474201  2025-06-03             800           803             367
# 474202  2025-06-03             800           803             369
# 474203  2025-06-03             800           803             376
# 474204  2025-06-03             800           803             376
# 474205  2025-06-03             800           803             376
#
#          libelle_arret    id_zdc               categorie_titre  nb_vald
# 474201    ISSY VAL SEI   71016.0                    NON DEFINI       67
# 474202  IVRY SUR SEINE  424396.0               Forfaits courts      473
# 474203           JAVEL   71150.0  Contrat Solidarité Transport      411
# 474204           JAVEL   71150.0               Forfaits courts     1147
# 474205           JAVEL   71150.0                     Imagine R     1172

# %%
donnees2.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 106590  2025-06-12             800           850             866
# 464616  2025-06-23             800           804             503
# 369112  2025-06-22             100           110             228
# 74937   2025-04-21             800           852             720
# 157062  2025-04-16             100           110             331
# 73604   2025-04-20             100           110             739
# 434264  2025-04-28             800           854             211
# 173326  2025-04-29             100           110              93
# 66312   2025-05-27             800           804             396
# 81585   2025-04-30             100           110             416
#
#          libelle_arret   id_zdc  categorie_titre  nb_vald
# 106590    VAIRES TORCY  68419.0   Forfait Navigo     2063
# 464616          MAISSE  59470.0        Imagine R       29
# 369112  CRX.DE CHAVAUX  71756.0  Forfaits courts     1433
# 74937      RAMBOUILLET  60665.0        Amethyste       43
# 157062        GLACIERE  71026.0       NON DEFINI      143
# 73604           RIQUET  71977.0    Autres titres       54
# 434264      CORMEILLES  65399.0       NON DEFINI       99
# 173326        BOTZARIS  71906.0       NON DEFINI       28
# 66312      FERTE ALAIS  59661.0   Forfait Navigo      151
# 81585       LA FOURCHE  71474.0    Autres titres       80

# %%
donnees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474206 entries, 0 to 474205
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   jour             474206 non-null  object
#  1   code_stif_trns   474206 non-null  int64
#  2   code_stif_res    474206 non-null  object
#  3   code_stif_arret  474206 non-null  object
#  4   libelle_arret    474206 non-null  object
#  5   id_zdc           473185 non-null  float64
#  6   categorie_titre  474206 non-null  object
#  7   nb_vald          474206 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 28.9+ MB

# %% [markdown]
# ## Troisième fichier

# %%
donnees3 = pd.read_excel(fichier.format("3eme"))

# %%
donnees3.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret   id_zdc  \
# 468221  2025-09-21             800           803              26  60072.0
# 468222  2025-09-21             800           803               3  69554.0
# 468223  2025-09-21             800           803              31  63134.0
# 468224  2025-09-21             800           803             326  72303.0
# 468225  2025-09-21             800           803             326  72303.0
#
#         libelle_arret               categorie_titre  nb_vald
# 468221        ARPAJON                Forfait Navigo      314
# 468222          ABLON  Contrat Solidarité Transport      134
# 468223     ATHIS MONS                Forfait Navigo      244
# 468224  GENNEVILLIERS               Forfaits courts      156
# 468225  GENNEVILLIERS                     Imagine R      223

# %%
donnees3.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret    id_zdc  \
# 119413  2025-08-23             100           110             689   71545.0
# 161887  2025-07-31             800           804             787   62290.0
# 56914   2025-08-25             100           110             920   71750.0
# 433711  2025-07-28             100           110             497   70645.0
# 306569  2025-08-10             100           110             671   70698.0
# 310864  2025-08-30             100           110              94  412992.0
# 16116   2025-07-05             800           804             428   60422.0
# 189907  2025-07-14             810           801             826   70393.0
# 230615  2025-07-12             800           822            1235   68293.0
# 56660   2025-08-25             100           110             479   71086.0
#
#           libelle_arret               categorie_titre  nb_vald
# 119413    PTE DE CLICHY                     Amethyste      445
# 161887  SAVIGNY LE TEMP                     Imagine R      607
# 56914          VOLTAIRE                Forfait Navigo     5037
# 433711   MAISON BLANCHE                 Autres titres       28
# 306569   PONT DE SEVRES  Contrat Solidarité Transport      437
# 310864        BOUCICAUT  Contrat Solidarité Transport      298
# 16116       BRAS DE FER                Forfait Navigo      578
# 189907    ST-MAUR-CRET.               Forfaits courts      546
# 230615   CRECY LA C T14  Contrat Solidarité Transport       12
# 56660           LOURMEL  Contrat Solidarité Transport      273

# %%
donnees3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468226 entries, 0 to 468225
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   jour             468226 non-null  object
#  1   code_stif_trns   468226 non-null  int64
#  2   code_stif_res    468226 non-null  object
#  3   code_stif_arret  468226 non-null  object
#  4   id_zdc           467625 non-null  float64
#  5   libelle_arret    468226 non-null  object
#  6   categorie_titre  468226 non-null  object
#  7   nb_vald          468226 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 28.6+ MB

# %% [markdown]
# ## Quatrième fichier

# %%
donnees4 = pd.read_excel(fichier.format("4eme"))

# %%
donnees4.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  id_zdc  \
# 287242  2025-11-07             800           854             175   69503
# 145214  2025-10-25             100           110            1229   72126
# 19241   2025-11-22             800           803             109   60028
# 60715   2025-12-22             100           110             273  479068
# 171660  2025-11-23             100           110             301   71808
# 416450  2025-10-02             100           110             614   71972
# 43172   2025-11-19             810           801             182   68385
# 245979  2025-12-29             800           803             825   59531
# 224518  2025-11-26             100           110             704   70636
# 56633   2025-10-28             100           110             416   71474
#
#           libelle_arret               categorie_titre  nb_vald
# 287242      CHAVILLE RD                Forfait Navigo     2015
# 145214   CLICHY ST-OUEN                Forfait Navigo     6152
# 19241   BREUILLET BRUYE  Contrat Solidarite Transport        5
# 60715    ETIENNE MARCEL                 Autres titres       72
# 171660         GAMBETTA                     Amethyste      330
# 416450            OURCQ                 Autres titres      140
# 43172      M.L.V.CHESSY                     Amethyste      124
# 245979        ST MARTIN  Contrat Solidarite Transport       57
# 224518     PORTE D'IVRY  Contrat Solidarite Transport      664
# 56633        LA FOURCHE                    NON DEFINI       26

# %%
donnees4.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  id_zdc  \
# 480640  2025-10-04             800           852             797  463754
# 480641  2025-10-04             800           852             813   73731
# 480642  2025-10-04             800           852             938   63812
# 480643  2025-10-04             800           852             938   63812
# 480644  2025-10-04             800           852             846   64194
#
#          libelle_arret               categorie_titre  nb_vald
# 480640       SEVRES RG                Forfait Navigo      657
# 480641          ST CYR  Contrat Solidarite Transport      217
# 480642  ST QUENTIN YVE                     Amethyste      131
# 480643  ST QUENTIN YVE                     Imagine R     1660
# 480644    TACOIGNIERES                     Amethyste        1

# %%
donnees4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480645 entries, 0 to 480644
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   jour             480645 non-null  object
#  1   code_stif_trns   480645 non-null  int64
#  2   code_stif_res    480645 non-null  object
#  3   code_stif_arret  480645 non-null  object
#  4   id_zdc           480645 non-null  int64
#  5   libelle_arret    480645 non-null  object
#  6   categorie_titre  480645 non-null  object
#  7   nb_vald          480645 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 29.3+ MB

# %% [markdown]
# # Concaténation des quatre fichiers en un dataframe Pandas - étude de ce dataframe
#
# On utilise les dataframes issus de l'examen des fichiers dans la partie précédente. C'est pour cela qu'on n'a pas recours à une boucle `for`.

# %%
df = pd.concat((donnees1, donnees2, donnees3, donnees4))
# vérification de la longueur du dataframe concaténé
len(df) == len(donnees1) + len(donnees2) + len(donnees3) + len(donnees4)
# Out:
# True

# %%
df.sample(15)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 66621   2025-03-24             800           804             114
# 388277  2025-11-19             800           854             157
# 38605   2025-05-02             100           110             533
# 190546  2025-07-15             800           804             117
# 108852  2025-01-26             100           110             618
# 230912  2025-07-12             810           801             913
# 146501  2025-09-11             800           854             508
# 95416   2025-12-16             800           851             284
# 137475  2025-12-20             800           854             435
# 414854  2025-01-05             800           854             399
# 410440  2025-01-09             100           110             652
# 449313  2025-03-12             100           110             628
# 366824  2025-01-02             100           110             671
# 216239  2025-12-11             100           110             420
# 371890  2025-01-16             800           852             813
#
#           libelle_arret      ida               categorie_titre  nb_vald  \
# 66621            BRUNOY  67476.0                 Autres titres       25
# 388277            CHARS      NaN                     Amethyste        1
# 38605      MENILMONTANT      NaN               Forfaits courts     1472
# 190546  BUNO GIRONVILLE      NaN  Contrat Solidarité Transport        4
# 108852     PALAIS-ROYAL  71297.0                     Imagine R     3177
# 230912        VINCENNES      NaN                     Imagine R     1960
# 146501   MANTES STATION      NaN  Contrat Solidarité Transport      240
# 95416     FONTAINEBLEAU      NaN                    NON DEFINI       80
# 137475            STADE      NaN                Forfait Navigo     1844
# 414854  GARENNE COLOMBE  72148.0                     Amethyste       23
# 410440   PLACE D'ITALIE  71033.0                     Amethyste     1370
# 449313          PASTEUR  71125.0                     Amethyste      361
# 366824   PONT DE SEVRES  70698.0               Forfaits courts      915
# 216239   LA MOTTE-PICQ.      NaN                    NON DEFINI      243
# 371890           ST CYR  73731.0               Forfaits courts       91
#
#          id_zdc
# 66621       NaN
# 388277  67352.0
# 38605   71815.0
# 190546  59447.0
# 108852      NaN
# 230912  71651.0
# 146501  65770.0
# 95416   61579.0
# 137475  72287.0
# 414854      NaN
# 410440      NaN
# 449313      NaN
# 366824      NaN
# 216239  71199.0
# 371890      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1892453 entries, 0 to 480644
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   jour             object
#  1   code_stif_trns   int64
#  2   code_stif_res    object
#  3   code_stif_arret  object
#  4   libelle_arret    object
#  5   ida              float64
#  6   categorie_titre  object
#  7   nb_vald          int64
#  8   id_zdc           float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 144.4+ MB

# %% [markdown]
# Dans le jeu de données, on ne conservera pas les champs `code_stif_arret`, `ida`, et `id_zdc`.
# On filtrera les données intéressantes sur les champs `code_stif_trns` et `code_stif_res`.
# On va prendre chaque colonne qu'on conservera ou sur laquelle on filtrera, la mettre en forme et le cas échéant vérifier sa conformité.
#
# ## Colonne `jour`
# On convertit cette colonne en type `date`, puis on vérifie que chaque jour de l'année 2025 est bien présent (comparaison au set `annee`de l'ensemble des jours de 2025).

# %%
df["jour"] = pd.to_datetime(df["jour"])
annee = {datetime64("2025-01-01") + timedelta64(i) for i in range(365)}
print(set(df["jour"]) == annee)    # pd.unique(df["jour"]) peut calculer plus vite
                                    # ou annee.difference(set(df["jour"]))
# Out:
# True

# %% [markdown]
# ## Colone `code_stif_trns`
#
# Il s'agit du code du transporteur. Seule la RATP, code 100 nous intéresse.

# %%
pd.unique(df['code_stif_trns'])
# Out:
# array([100, 760, 762, 800, 810, 761, 764])

# %%
df = df[df['code_stif_trns'] == 100]

# %% [markdown]
# ## Colonne `code_stif_res`
#
# Il s'agit du code du réseau. Seul le code 110, correspondant au métro, nous intéresse.

# %%
pd.unique(df['code_stif_res'])
# Out:
# array(['110', 'ND'], dtype=object)

# %% [markdown]
# On doit éliminer les données du réseau 'ND'. Cependant on regarde avant la proportion de `nb_vald` (la variable quantitative que l'on va étudier) que cela représente.

# %%
df[df['code_stif_res']=='ND']['nb_vald'].sum()/df['nb_vald'].sum()
# Out:
# np.float64(0.000417352438591083)

# %% [markdown]
# Ce nombre est négligeable.

# %%
df = df[df['code_stif_res']=='110']

# %% [markdown]
# ## Colonne `libelle_arret`

# %%
sorted(pd.unique(df['libelle_arret']))
# Out:
# ['ABBESSES',
#  'AIME CESAIRE',
#  'ALESIA',
#  'ALEXANDR.DUMAS',
#  'ALFORT-ECOLE V',
#  'ALMA-MARCEAU',
#  'ANATOLE FRANCE',
#  'ANTONY',
#  'ANVERS',
#  'ARGENTINE',
#  'ARTS.METIERS',
#  'ASSEMBLEE NAT.',
#  'AUBERV.4 CHEM.',
#  'AV.EMILE ZOLA',
#  'AVRON',
#  'BALARD',
#  'BARBARA',
#  'BARBES-ROCH.',
#  'BASTILLE',
#  'BEL AIR',
#  'BELLEVILLE',
#  'BERAULT',
#  'BERCY',
#  'BIBLIOTHEQUE',
#  'BILLANCOURT',
#  'BIR-HAKEIM',
#  'BLANCHE',
#  'BOB.P.PICASSO',
#  'BOB.R.QUENEAU',
#  'BOISSIERE',
#  'BOLIVAR',
#  'BONNE NOUVELLE',
#  'BOTZARIS',
#  'BOUCICAUT',
#  'BOULETS-MONTR.',
#  'BOULOGNE-J.J.',
#  'BOULOGNE-ST.CL',
#  'BOURSE',
#  'BREGUET-SABIN',
#  'BROCHANT',
#  'BUTTES-CHAUM.',
#  'BUZENVAL',
#  'CADET',
#  'CAMBRONNE',
#  'CAMPO-FORMIO',
#  'CARD.LEMOINE',
#  'CARREF.PLEYEL',
#  'CENSIER DAUB.',
#  'CH.D.G.ETOILE',
#  'CH.D.VINCENNES',
#  'CHAMPS-ELYSEES',
#  'CHARDON-LAGACH',
#  'CHARENTON-ECO.',
#  'CHARL.MICHELS',
#  'CHARONNE',
#  "CHATEAU D'EAU",
#  'CHATEAU ROUGE',
#  'CHATEAU-LANDON',
#  'CHATELET',
#  'CHATILLON-MON.',
#  "CHAUSS.D'ANTIN",
#  'CHEMIN-VERT',
#  'CHEVALERET',
#  'CHEVILLY-LARUE',
#  'CITE',
#  'CLICHY ST-OUEN',
#  'COLONEL FABIEN',
#  'COMMERCE',
#  'CONCORDE',
#  'CONVENTION',
#  'CORENT.CARIOU',
#  'CORENT.CELTON',
#  'CORVISART',
#  'COT. BEAUCLAIR',
#  'COUR ST-EMILI.',
#  'COURCELLES',
#  'COURONNES',
#  'CRETEIL-ECHAT',
#  'CRETEIL-P. LAC',
#  'CRETEIL-PREF.',
#  'CRETEIL-UNIV.',
#  'CRIMEE',
#  'CRX.DE CHAVAUX',
#  'DANUBE',
#  'DAUMESNIL',
#  'DENFERT-ROCH.',
#  'DUGOMMIER',
#  'DUPLEIX',
#  'DUROC',
#  'EC.MILITAIRE',
#  'EDGAR QUINET',
#  "EGLI.D'AUTEUIL",
#  'EGLI.DE PANTIN',
#  'ESPLANADE DEF.',
#  'ETIENNE MARCEL',
#  'EUROPE',
#  'EXELMANS',
#  'F.D.ROOSEVELT',
#  'FAIDHERBE-CHA.',
#  'FALGUIERE',
#  'FELIX FAURE',
#  'FILLES DU CALV',
#  "FORT D'AUBERV.",
#  'FR. POPULAIRE',
#  'FUNICULAIRE',
#  'GABRIEL PERI',
#  'GAITE',
#  'GALLIENI',
#  'GAMBETTA',
#  "GARE D'AUSTER.",
#  "GARE DE L'EST",
#  'GARE DE LYON',
#  'GARE DU NORD',
#  'GARIBALDI',
#  'GDS BOULEVARDS',
#  'GEORGE V',
#  'GLACIERE',
#  'GONCOURT',
#  'GUY MOQUET',
#  'HAVR.CAUMARTIN',
#  'HOCHE',
#  'HOP. BICETRE',
#  'HOTEL DE VILLE',
#  'IENA',
#  'INVALIDES',
#  'J.BONSERGENT',
#  'JASMIN',
#  'JAURES',
#  'JAVEL',
#  'JOURDAIN',
#  'JULES JOFFRIN',
#  'JUSSIEU',
#  'KLEBER',
#  'KREML.BICETRE',
#  "L'HAY-LES-ROSE",
#  'LA CHAPELLE',
#  'LA COURNEUVE',
#  'LA DEFENSE',
#  'LA DHUYS',
#  'LA FOURCHE',
#  'LA MOTTE-PICQ.',
#  'LA MUETTE',
#  'LAMARCK-CAUL.',
#  'LATOUR-MAUB.',
#  'LAUMIERE',
#  'LE PELETIER',
#  'LEDRU-ROLLIN',
#  'LES AGNETTES',
#  'LES COURTILLES',
#  'LES GOBELINS',
#  'LES HALLES',
#  'LES SABLONS',
#  'LIBERTE',
#  'LIEGE',
#  'LOUIS BLANC',
#  'LOUISE MICHEL',
#  'LOURMEL',
#  'LOUVRE',
#  'LUCIE AUBRAC',
#  'M. MONTROUGE',
#  'M.ANGE-AUTEUIL',
#  'M.ANGE-MOLITOR',
#  'MABILLON',
#  'MADELEINE',
#  'MAIRIE CLICHY',
#  "MAIRIE D'AUBERVILLIERS",
#  "MAIRIE D'ISSY",
#  "MAIRIE D'IVRY",
#  'MAIRIE D.LILAS',
#  'MAIRIE D.MONT',
#  'MAIRIE ST-OUEN',
#  'MAIS.ALF-JUIL.',
#  'MAIS.ALF-STADE',
#  'MAISON BLANCHE',
#  'MALAK-P.VANVES',
#  'MALAK.ET.DOLET',
#  'MALESHERBES',
#  'MARAICHERS',
#  'MARCADET-POIS.',
#  'MARCEL SEMBAT',
#  'MARX DORMOY',
#  'MAUBERT-MUTUA.',
#  'MENILMONTANT',
#  'MICHEL BIZOT',
#  'MIRABEAU',
#  'MIROMESNIL',
#  'MONCEAU',
#  'MONTGALLET',
#  'MONTPARNASSE',
#  'MONTREUIL HOP.',
#  'MOUTON-DUVERN.',
#  'N.D.DE-LORETTE',
#  'N.D.DES-CHAMPS',
#  'NATION',
#  'NATIONALE',
#  'OBERKAMPF',
#  'ODEON',
#  'OLYMPIADES',
#  'OPERA',
#  'OURCQ',
#  'PALAIS-ROYAL',
#  'PARMENTIER',
#  'PASSY',
#  'PASTEUR',
#  'PELLEPORT',
#  'PERE-LACHAISE',
#  'PEREIRE',
#  'PERNETY',
#  'PHIL.AUGUSTE',
#  'PICPUS',
#  'PIERRE CURIE',
#  'PIGALLE',
#  'PLACE CLICHY',
#  "PLACE D'ITALIE",
#  'PLACE D. FETES',
#  'PLACE MONGE',
#  'PLAISANCE',
#  'POISSONNIERE',
#  'PONT CARDINET',
#  'PONT D.NEUILLY',
#  'PONT DE SEVRES',
#  'PONT LEVALLOIS',
#  'PONT MARIE',
#  'PONT-NEUF',
#  "PORTE D'ITALIE",
#  "PORTE D'IVRY",
#  'PORTE D.CLIGN.',
#  'PORTE D.LILAS',
#  'PORTE D.VANVES',
#  'PORTE D.VERS.',
#  'PORTE DAUPHINE',
#  'PORTE DOREE',
#  'PORTE MAILLOT',
#  'PRE-ST-GERVAIS',
#  'PTE CHAMPERRET',
#  'PTE CHARENTON',
#  "PTE D'AUTEUIL",
#  "PTE D'ORLEANS",
#  'PTE D. VINCENN',
#  'PTE D.BAGNOLET',
#  'PTE D.CHAPELLE',
#  'PTE D.ST-OUEN',
#  'PTE D.VILLETTE',
#  'PTE DE CHOISY',
#  'PTE DE CLICHY',
#  'PTE DE PANTIN',
#  'PTE MONTREUIL',
#  'PTE ST-CLOUD',
#  'PYRAMIDES',
#  'PYRENEES',
#  'QUAI D.LA GARE',
#  'QUAI.LA RAPEE',
#  'QUATRE-SEPTEMB',
#  'RAMBUTEAU',
#  'RANELAGH',
#  'RASPAIL',
#  'REAUMUR-SEB.',
#  'RENNES',
#  'REPUBLIQUE',
#  'REUILLY-DID.',
#  'RICHARD LENOIR',
#  'RICHELIEU-DR.',
#  'RIQUET',
#  'ROBESPIERRE',
#  'ROMAINV.CARNOT',
#  'ROME',
#  'ROSNY BOIS.P',
#  'RUE D.LA POMPE',
#  'RUE DU BAC',
#  'S. GAINSBOURG',
#  'SAINT-AMBROISE',
#  'SAINT-AUGUSTIN',
#  'SAINT-FARGEAU',
#  'SAINT-GEORGES',
#  'SAINT-JACQUES',
#  'SAINT-LAZARE',
#  'SAINT-MARCEL',
#  'SAINT-MAUR',
#  'SAINT-MICHEL',
#  'SAINT-PAUL',
#  'SAINT-PLACIDE',
#  'SAINT-SULPICE',
#  'SEGUR',
#  'SENTIER',
#  'SEVRES-BABYL.',
#  'SEVRES-LECOUR.',
#  'SIMPLON',
#  'SOLFERINO',
#  'ST-DENIS-BASIL',
#  'ST-DENIS-PTE P',
#  'ST-DENIS-UNIV.',
#  'ST-FRAN.XAVIER',
#  'ST-GERM.D.PRES',
#  'ST-MANDE TOUR.',
#  'ST-PH.DU-ROULE',
#  'ST-SEBASTIEN.F',
#  'STALINGRAD',
#  'STRAS.ST-DENIS',
#  'SULLY-MORLAND',
#  'TELEGRAPHE',
#  'TEMPLE',
#  'TERNES',
#  'THIAIS-ORLY',
#  'TOLBIAC',
#  'TRINITE',
#  'TROCADERO',
#  'TUILERIES',
#  'VANEAU',
#  'VARENNE',
#  'VAUGIRARD',
#  'VAVIN',
#  'VICTOR HUGO',
#  'VILLEJ.L.ARAG.',
#  'VILLEJ.L.LAGR.',
#  'VILLEJ.P.V.C',
#  'VILLIERS',
#  'VOLONTAIRES',
#  'VOLTAIRE',
#  'WAGRAM']

# %% [markdown]
# En comparant à lal liste des stations de métro <https://fr.wikipedia.org/wiki/Liste_des_stations_du_m%C3%A9tro_de_Paris>, on note la présence de deux stations supplémentaires dans notre jeu de données :
# - ANTONY : pourquoi ?
# - FUNICULAIRE : on conserve cette station.

# %%
df[df['libelle_arret'] == 'ANTONY']
# Out:
#              jour  code_stif_trns code_stif_res code_stif_arret libelle_arret  \
# 4743   2025-09-24             100           110              19        ANTONY
# 134536 2025-09-11             100           110              19        ANTONY
# 146054 2025-09-10             100           110              19        ANTONY
# 150479 2025-09-22             100           110              19        ANTONY
# 175401 2025-09-29             100           110              19        ANTONY
# 176491 2025-09-25             100           110              19        ANTONY
# 274400 2025-09-11             100           110              19        ANTONY
# 39360  2025-11-19             100           110              19        ANTONY
# 55100  2025-11-07             100           110              19        ANTONY
# 119593 2025-11-19             100           110              19        ANTONY
# 380424 2025-11-14             100           110              19        ANTONY
# 476232 2025-10-08             100           110              19        ANTONY
#
#         ida               categorie_titre  nb_vald   id_zdc
# 4743    NaN               Forfaits courts        2  69759.0
# 134536  NaN                    NON DEFINI        1  69759.0
# 146054  NaN                Forfait Navigo        1  69759.0
# 150479  NaN                Forfait Navigo        1  69759.0
# 175401  NaN               Forfaits courts        1  69759.0
# 176491  NaN               Forfaits courts        1  69759.0
# 274400  NaN  Contrat Solidarité Transport        1  69759.0
# 39360   NaN  Contrat Solidarite Transport        1  69759.0
# 55100   NaN                Forfait Navigo        2  69759.0
# 119593  NaN               Forfaits courts        6  69759.0
# 380424  NaN                Forfait Navigo        2  69759.0
# 476232  NaN                Forfait Navigo        1  69759.0

# %% [markdown]
# Au vu des très faibles effectifs, il s'agit vraisemblablement d'une erreur. On supprime ces occurrences :

# %%
df = df[df['libelle_arret'] != "ANTONY"]

# %% [markdown]
# On note également 4 stations manquantes :
# - *Villejuif-Gustave-Roussy* : ouverte en janvier 2025 et non exploitée par la RATP,
# - *Aéroport d'Orly* : tarification spécifique et non exploitée par la RATP,
# - *Saint-Denis-Pleyel* : non exploitée par la RATP,
# - *Cluny-La-Sorbonne* : *peut-être* du fait de sa liaison avec *Saint-Michel* ? Pas d'explicaton formelle.

# %% [markdown]
# ## Colonne `categorie_titre`

# %%
pd.unique(df['categorie_titre'])
# Out:
# array(['Forfaits courts', 'Autres titres', 'Contrat Solidarité Transport',
#        'Forfait Navigo', 'Imagine R', 'Amethyste', 'NON DEFINI',
#        'Contrat Solidarite Transport'], dtype=object)

# %% [markdown]
# **On remarque la présence de "Contrat Solidarité Transport" *et* de "Contrat Solidarite Transport" ; on corrige ce dernier libellé :**

# %%
df = df.replace("Contrat Solidarite Transport", "Contrat Solidarité Transport")
pd.unique(df['categorie_titre'])
# Out:
# array(['Forfaits courts', 'Autres titres', 'Contrat Solidarité Transport',
#        'Forfait Navigo', 'Imagine R', 'Amethyste', 'NON DEFINI'],
#       dtype=object)

# %% [markdown]
# On calcule la proportion de `nb_valid` avec `categorie_titre` 'NON DEFINI' :

# %%
df[df['categorie_titre']=='NON DEFINI']['nb_vald'].sum()/df['nb_vald'].sum()
# Out:
# np.float64(0.010595519436082146)

# %% [markdown]
# On choisit de conserver cette modalité, bien que peu significative.

# %% [markdown]
# ## Colonne `nb_vald`
#
# Il s'agit de la seule colonne quantitative que nous allons étudier

# %%
df['nb_vald'].groupby(df['categorie_titre']).describe()
# Out:
#                                  count         mean          std  min     25%  \
# categorie_titre
# Amethyste                     114974.0   256.423000   229.219000  1.0   110.0
# Autres titres                 114908.0   204.790250   394.783402  1.0    52.0
# Contrat Solidarité Transport  115102.0  1005.118304  1143.164582  1.0   374.0
# Forfait Navigo                115454.0  5655.685234  5722.240091  1.0  2610.0
# Forfaits courts               115014.0  1917.825665  2674.105964  1.0   721.0
# Imagine R                     115046.0  1758.261391  1716.595560  1.0   787.0
# NON DEFINI                    115904.0   114.989146   129.726791  1.0    44.0
#
#                                  50%      75%      max
# categorie_titre
# Amethyste                      193.0   318.00   2693.0
# Autres titres                   98.0   209.00  12481.0
# Contrat Solidarité Transport   666.0  1200.00  14491.0
# Forfait Navigo                4333.0  6882.75  92195.0
# Forfaits courts               1163.0  1966.75  42157.0
# Imagine R                     1350.0  2178.00  30768.0
# NON DEFINI                      72.0   128.00   1400.0

# %% [markdown]
# **On remarque qu'il y a des valeurs inférieures à 5, contrairement à ce qui est spécifié dans la documentation du jeu de données.**

# %% [markdown]
# ## Création du fichier source
#
# ### Suppression des colonnes inutiles

# %%
df = df.drop(['code_stif_trns', 'code_stif_res', 'code_stif_arret', 'ida', 'id_zdc'], axis=1)
df
# Out:
#              jour   libelle_arret               categorie_titre  nb_vald
# 0      2025-03-07       MADELEINE               Forfaits courts     3387
# 1      2025-03-07    BARBES-ROCH.                 Autres titres      478
# 2      2025-03-07   S. GAINSBOURG  Contrat Solidarité Transport      781
# 3      2025-03-07   S. GAINSBOURG                Forfait Navigo     2880
# 4      2025-03-07   S. GAINSBOURG                     Imagine R     1158
# ...           ...             ...                           ...      ...
# 480466 2025-10-04  VILLEJ.L.LAGR.                 Autres titres       49
# 480467 2025-10-04  VILLEJ.L.LAGR.  Contrat Solidarité Transport      591
# 480468 2025-10-04     VOLONTAIRES                 Autres titres       45
# 480469 2025-10-04     VOLONTAIRES  Contrat Solidarité Transport      226
# 480470 2025-10-04     VOLONTAIRES               Forfaits courts     1158
#
# [806402 rows x 4 columns]

# %% [markdown]
# ### Recherche de lignes doublonnées
#
# Le jeu données ne devrait *théoriquement* plus comporter de **doublons (même jour, même arrêt, même catégorie de titre)**, mais il faut le verifier :

# %%
df_agr = df.groupby(
    ["jour", "libelle_arret", "categorie_titre"]
)["nb_vald"].count()

doublons = df_agr[df_agr > 1]
doublons
# Out:
# jour        libelle_arret   categorie_titre
# 2025-01-01  MAIRIE ST-OUEN  Amethyste                       2
#                             Autres titres                   2
#                             Contrat Solidarité Transport    2
#                             Forfait Navigo                  2
#                             Forfaits courts                 2
#                                                            ..
# 2025-12-31  PTE DE CLICHY   Contrat Solidarité Transport    2
#                             Forfait Navigo                  2
#                             Forfaits courts                 2
#                             Imagine R                       2
#                             NON DEFINI                      2
# Name: nb_vald, Length: 5689, dtype: int64

# %% [markdown]
# On trouve un **grand nombre de doublons**, qu'il va falloir examminer :

# %%
doublons.sample(10)
# Out:
# jour        libelle_arret   categorie_titre
# 2025-11-04  MAISON BLANCHE  Autres titres                   2
# 2025-08-05  MAIRIE ST-OUEN  Forfait Navigo                  2
# 2025-11-03  PTE DE CLICHY   Autres titres                   2
# 2025-07-04  MAISON BLANCHE  Forfaits courts                 2
# 2025-02-22  MAIRIE ST-OUEN  Contrat Solidarité Transport    2
# 2025-11-09  MAISON BLANCHE  Forfaits courts                 2
# 2025-11-02  PTE DE CLICHY   NON DEFINI                      2
# 2025-07-28  MAIRIE ST-OUEN  Amethyste                       2
# 2025-10-21  MAISON BLANCHE  Forfait Navigo                  2
# 2025-08-11  MAISON BLANCHE  Amethyste                       2
# Name: nb_vald, dtype: int64

# %%
pd.unique(doublons.reset_index()["libelle_arret"])
# Out:
# array(['MAIRIE ST-OUEN', 'MAISON BLANCHE', 'PTE DE CLICHY'], dtype=object)

# %% [markdown]
# Ces doublons ne concernent donc que **trois stations**.

# %%
len(pd.unique(doublons.reset_index()["jour"]))
# Out:
# 365

# %% [markdown]
# Mais ils s'étalent sur **toute l'année**.
# On examine un échantillon de ces doublons, en faisant tourner plusieurs fois le code suivant :

# %%
# Échantillon du jeu de données sur 1 date aléatoire, pour les 3 stations présentant des doublons
df[(df["libelle_arret"].isin(pd.unique(doublons.reset_index()["libelle_arret"]))) \
    & (df["jour"].isin(df["jour"].sample(1)))] \
    .sort_values(["jour", "libelle_arret", "categorie_titre"])
# Out:
#              jour   libelle_arret               categorie_titre  nb_vald
# 422564 2025-04-04  MAIRIE ST-OUEN                     Amethyste      256
# 422738 2025-04-04  MAIRIE ST-OUEN                     Amethyste      164
# 9461   2025-04-04  MAIRIE ST-OUEN                 Autres titres       79
# 119947 2025-04-04  MAIRIE ST-OUEN                 Autres titres      213
# 194989 2025-04-04  MAIRIE ST-OUEN  Contrat Solidarité Transport     2354
# 342262 2025-04-04  MAIRIE ST-OUEN  Contrat Solidarité Transport      863
# 9462   2025-04-04  MAIRIE ST-OUEN                Forfait Navigo     2919
# 194990 2025-04-04  MAIRIE ST-OUEN                Forfait Navigo     9772
# 195182 2025-04-04  MAIRIE ST-OUEN               Forfaits courts      604
# 342061 2025-04-04  MAIRIE ST-OUEN               Forfaits courts     1694
# 194991 2025-04-04  MAIRIE ST-OUEN                     Imagine R     2708
# 422739 2025-04-04  MAIRIE ST-OUEN                     Imagine R      743
# 9264   2025-04-04  MAIRIE ST-OUEN                    NON DEFINI      181
# 120134 2025-04-04  MAIRIE ST-OUEN                    NON DEFINI       57
# 195134 2025-04-04  MAISON BLANCHE                     Amethyste      354
# 422745 2025-04-04  MAISON BLANCHE                     Amethyste      169
# 120080 2025-04-04  MAISON BLANCHE                 Autres titres      169
# 342268 2025-04-04  MAISON BLANCHE                 Autres titres      118
# 195183 2025-04-04  MAISON BLANCHE  Contrat Solidarité Transport      504
# 342219 2025-04-04  MAISON BLANCHE  Contrat Solidarité Transport     1330
# 9417   2025-04-04  MAISON BLANCHE                Forfait Navigo     6750
# 342269 2025-04-04  MAISON BLANCHE                Forfait Navigo     2893
# 9418   2025-04-04  MAISON BLANCHE               Forfaits courts     1173
# 120143 2025-04-04  MAISON BLANCHE               Forfaits courts      527
# 9466   2025-04-04  MAISON BLANCHE                     Imagine R     1126
# 342220 2025-04-04  MAISON BLANCHE                     Imagine R     3341
# 195135 2025-04-04  MAISON BLANCHE                    NON DEFINI      144
# 342270 2025-04-04  MAISON BLANCHE                    NON DEFINI       34
# 120232 2025-04-04   PTE DE CLICHY                     Amethyste      753
# 120233 2025-04-04   PTE DE CLICHY                 Autres titres      952
# 422828 2025-04-04   PTE DE CLICHY  Contrat Solidarité Transport     3835
# 120234 2025-04-04   PTE DE CLICHY                Forfait Navigo    15246
# 9559   2025-04-04   PTE DE CLICHY               Forfaits courts     2790
# 195273 2025-04-04   PTE DE CLICHY                     Imagine R     6250
# 120235 2025-04-04   PTE DE CLICHY                    NON DEFINI      272

# %% [markdown]
# **Conclusion : les lignes en doublon comportent de nombre de validations à la fois significatifs et différents. En l'absence d'explication, on décide de les *agréger par somme*.**
#
# ### Traitement par agrégation des lignes en doublon

# %%
# as_index=False : très important pour garder un jeu de données exportable proprement !
df = df.groupby(by=['jour', 'libelle_arret', 'categorie_titre'], as_index=False).aggregate("sum")
df
# Out:
#              jour libelle_arret               categorie_titre  nb_vald
# 0      2025-01-01      ABBESSES                     Amethyste       18
# 1      2025-01-01      ABBESSES                 Autres titres     1042
# 2      2025-01-01      ABBESSES  Contrat Solidarité Transport       96
# 3      2025-01-01      ABBESSES                Forfait Navigo     1302
# 4      2025-01-01      ABBESSES               Forfaits courts     1059
# ...           ...           ...                           ...      ...
# 800708 2025-12-31        WAGRAM  Contrat Solidarité Transport      180
# 800709 2025-12-31        WAGRAM                Forfait Navigo     1517
# 800710 2025-12-31        WAGRAM               Forfaits courts      620
# 800711 2025-12-31        WAGRAM                     Imagine R      349
# 800712 2025-12-31        WAGRAM                    NON DEFINI       20
#
# [800713 rows x 4 columns]

# %% [markdown]
# ### Export du fichier des données traitées
#
# Le fichier est exporté dans le répertoire parent de celui depuis lequel ce notebook est lancé. Selon l'arborescence du projet, cela correspond au **répertoire racine du projet**des.

# %%
# durée : environ 1 min 30
df.to_excel("../data_traitee.xlsx", sheet_name="DATA", na_rep="NA", index=False)
