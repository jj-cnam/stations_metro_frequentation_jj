# %% [markdown]
# ### Exploration préparatoire des données ###

# %%
import os
import s3fs
import pandas as pd
import openpyxl

# %%
# Connexion au dépôt de données
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': "https://" + os.environ["AWS_S3_ENDPOINT"]})
# Récupération de la liste des fichiers
fichiers = fs.ls("jacquemmoz")

# %% [markdown]
# # Examen des fichiers
#
# ## Premier fichier

# %%
# long (42.4s) ==> cellule désactivée
#with fs.open(fichiers[0], mode="rb") as fichier:
#    donnees = pd.read_excel(fichier)

# %%
donnees.head()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 365252  2025-01-29             800           803             402
# 222150  2025-01-20             100           110             275
# 25807   2025-03-18             100           110             362
# 138723  2025-01-14             800           852             938
# 221544  2025-01-19             800           803             361
# 411444  2025-01-10             100           110             555
# 228180  2025-01-31             100           110             466
# 276175  2025-03-26             800           803             540
# 221004  2025-01-18             810           801             913
# 220394  2025-01-18             100           110             696
#
#           libelle_arret    ida               categorie_titre  nb_vald
# 365252  NORVILLE ST GER  60115                     Imagine R      171
# 222150           EUROPE  73617                     Amethyste       97
# 25807         INVALIDES  71274                    NON DEFINI      163
# 138723   ST QUENTIN YVE  63812                Forfait Navigo    10828
# 221544        INVALIDES  71274  Contrat Solidarité Transport       76
# 411444       MONTGALLET  71631               Forfaits courts      189
# 228180          LIBERTE  71558                     Amethyste      164
# 276175  MEUDON VAL FLEU  70412                    NON DEFINI       16
# 221004        VINCENNES  71651                 Autres titres       49
# 220394    PTE D.ST-OUEN  72078                     Amethyste      305

# %%
donnees.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 469371  2025-03-01             800           853             485
# 469372  2025-03-01             800           853             536
# 469373  2025-03-01             800           853             536
# 469374  2025-03-01             800           853             568
# 469375  2025-03-01             800           853             568
#
#        libelle_arret    ida  categorie_titre  nb_vald
# 469371     LUZARCHES  67177   Forfait Navigo       47
# 469372        MERIEL  67065        Amethyste        2
# 469373        MERIEL  67065        Imagine R       50
# 469374     MONTSOULT  67000   Forfait Navigo      286
# 469375     MONTSOULT  67000  Forfaits courts       57

# %%
donnees.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 409730  2025-02-02             800           803             639
# 136103  2025-01-04             800           803             832
# 435954  2025-02-28             100           110             773
# 105801  2025-01-21             100           110             842
# 396296  2025-02-11             100           110             762
# 425139  2025-01-08             100           110             318
# 377231  2025-01-17             800           803             335
# 441420  2025-03-14             100           110             492
# 149915  2025-02-25             100           110             640
# 335039  2025-03-29             800           804             643
#
#            libelle_arret    ida               categorie_titre  nb_vald
# 409730        PETIT VAUX  60985                Forfait Navigo       21
# 136103           ST OUEN  72126                 Autres titres        3
# 435954      SAINT-MARCEL  71092                     Imagine R     1536
# 105801     SULLY-MORLAND  71201                     Imagine R     1838
# 396296    ST-DENIS-PTE P  72285                Forfait Navigo     6113
# 425139      GARE DU NORD  71410                     Imagine R     2572
# 377231  GRAVIGNY BAL T12  62667                 Autres titres        2
# 441420     MAIRIE D.MONT  71785  Contrat Solidarité Transport     3452
# 149915      PHIL.AUGUSTE  71751                    NON DEFINI       44
# 335039   PIERREFITTE STA  72787                     Amethyste       88

# %%
donnees.dtypes
# Out:
# jour               object
# code_stif_trns      int64
# code_stif_res      object
# code_stif_arret    object
# libelle_arret      object
# ida                 int64
# categorie_titre    object
# nb_vald             int64
# dtype: object

# %% [markdown]
# On voit d'ores et déjà qu'il faudra recoder la colonne 'jour' pour la transformer en type date.
# La colonne nb_val est bien un entier.
# Les autres colonnes seront utilisables telles quelles : soit on les utilisera comme chaînes de caractères, soit uniquement pour un premier tri des données avant suppression.

# %% [markdown]
# ## Second fichier

# %%
with fs.open(fichiers[1], mode="rb") as fichier:
    donnees = pd.read_excel(fichier)
donnees.head()
# Out:
#          jour  code_stif_trns code_stif_res code_stif_arret libelle_arret  \
# 0  2025-04-12             100           110             861       TRINITE
# 1  2025-04-12             100           110             862     TROCADERO
# 2  2025-04-12             100           110             862     TROCADERO
# 3  2025-04-12             100           110             864     TUILERIES
# 4  2025-04-12             100           110             864     TUILERIES
#
#     id_zdc               categorie_titre  nb_vald
# 0  71355.0                    NON DEFINI       73
# 1  71285.0               Forfaits courts    12487
# 2  71285.0                     Imagine R     3092
# 3  71284.0                     Amethyste       56
# 4  71284.0  Contrat Solidarité Transport      267

# %%
donnees.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 474201  2025-06-03             800           803             367
# 474202  2025-06-03             800           803             369
# 474203  2025-06-03             800           803             376
# 474204  2025-06-03             800           803             376
# 474205  2025-06-03             800           803             376
#
#          libelle_arret    id_zdc               categorie_titre  nb_vald
# 474201    ISSY VAL SEI   71016.0                    NON DEFINI       67
# 474202  IVRY SUR SEINE  424396.0               Forfaits courts      473
# 474203           JAVEL   71150.0  Contrat Solidarité Transport      411
# 474204           JAVEL   71150.0               Forfaits courts     1147
# 474205           JAVEL   71150.0                     Imagine R     1172

# %%
donnees.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  \
# 465647  2025-06-28             100           110             736
# 210491  2025-04-05             800           803             590
# 78925   2025-04-23             800           852             858
# 321251  2025-06-08             100           110             144
# 202743  2025-04-09             800           850             516
# 193235  2025-04-02             100           110             892
# 336879  2025-05-13             100           110             741
# 223227  2025-05-20             800           804             106
# 91332   2025-06-25             800           853             568
# 266741  2025-04-07             800           803             793
#
#          libelle_arret   id_zdc               categorie_titre  nb_vald
# 465647  RICHARD LENOIR  73648.0               Forfaits courts     1213
# 210491   PORTE MAILLOT  71379.0               Forfaits courts      278
# 78925          TRAPPES  63650.0                 Autres titres        6
# 321251  CHAMPS-ELYSEES  71305.0                     Amethyste      144
# 202743  MARLES EN BRIE  67604.0  Contrat Solidarité Transport       18
# 193235     VICTOR HUGO  71315.0                Forfait Navigo     7174
# 336879     ROBESPIERRE  71725.0                     Imagine R     1674
# 223227        BOUTIGNY  59565.0                     Amethyste        3
# 91332        MONTSOULT  67000.0  Contrat Solidarité Transport      171
# 266741        SERMAISE  59842.0                    NON DEFINI        2

# %%
donnees.dtypes
# Out:
# jour                object
# code_stif_trns       int64
# code_stif_res       object
# code_stif_arret     object
# libelle_arret       object
# id_zdc             float64
# categorie_titre     object
# nb_vald              int64
# dtype: object

# %% [markdown]
# # Troisième fichier

# %%
with fs.open(fichiers[2], mode="rb") as fichier:
    donnees = pd.read_excel(fichier)
donnees.head()
# Out:
#          jour  code_stif_trns code_stif_res code_stif_arret   id_zdc  \
# 0  2025-09-21             810           801             393  71517.0
# 1  2025-09-21             810           801             431  70359.0
# 2  2025-09-21             810           801             438  64514.0
# 3  2025-09-21             810           801             473  68123.0
# 4  2025-09-21             810           801             473  68123.0
#
#     libelle_arret  categorie_titre  nb_vald
# 0      LA DEFENSE  Forfaits courts     7732
# 1  LE PARC S.MAUR       NON DEFINI       47
# 2  LE VESINET-CEN    Autres titres       10
# 3          LOGNES        Imagine R      521
# 4          LOGNES       NON DEFINI       28

# %%
donnees.tail()
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret   id_zdc  \
# 468221  2025-09-21             800           803              26  60072.0
# 468222  2025-09-21             800           803               3  69554.0
# 468223  2025-09-21             800           803              31  63134.0
# 468224  2025-09-21             800           803             326  72303.0
# 468225  2025-09-21             800           803             326  72303.0
#
#         libelle_arret               categorie_titre  nb_vald
# 468221        ARPAJON                Forfait Navigo      314
# 468222          ABLON  Contrat Solidarité Transport      134
# 468223     ATHIS MONS                Forfait Navigo      244
# 468224  GENNEVILLIERS               Forfaits courts      156
# 468225  GENNEVILLIERS                     Imagine R      223

# %% [markdown]
# donnees.sample(10)

# %% [markdown]
# donnees.dtypes

# %% [markdown]
# ## Quatrième fichier

# %%
with fs.open(fichiers[3], mode="rb") as fichier:
    donnees = pd.read_excel(fichier)
donnees.head()
# Out:
#          jour  code_stif_trns code_stif_res code_stif_arret  id_zdc  \
# 0  2025-10-31             800           803             454   69662
# 1  2025-10-31             800           803             454   69662
# 2  2025-10-31             800           803             788   60987
# 3  2025-10-31             800           803             793   59842
# 4  2025-10-31             800           803             793   59842
#
#      libelle_arret  categorie_titre  nb_vald
# 0           SAULES    Autres titres        1
# 1           SAULES  Forfaits courts      188
# 2  SAVIGNY SUR ORG        Imagine R     1263
# 3         SERMAISE        Amethyste        1
# 4         SERMAISE   Forfait Navigo       42

# %%
donnees.sample(10)
# Out:
#               jour  code_stif_trns code_stif_res code_stif_arret  id_zdc  \
# 420723  2025-10-09             800           854             527   65827
# 7459    2025-12-08             100           110             253   72024
# 30112   2025-11-15             800           854             464   73603
# 107672  2025-11-01             810           802              20   69759
# 49218   2025-12-24             810           801             580   70940
# 302254  2025-12-02             100           110             199   71298
# 221016  2025-12-24             800           805             967   67625
# 12318   2025-10-08             800           854              92   66741
# 296689  2025-10-25             800           853             143   65663
# 37739   2025-10-24             800           853             890   67176
#
#           libelle_arret               categorie_titre  nb_vald
# 420723       MAURECOURT                 Autres titres        6
# 7459     EGLI.DE PANTIN  Contrat Solidarite Transport     1515
# 30112    ETANG LA VILLE                     Amethyste        5
# 107672           ANTONY                 Autres titres       12
# 49218    NANTERRE-VILLE                 Autres titres       26
# 302254         CONCORDE                     Imagine R     2296
# 221016          TOURNAN                    NON DEFINI        5
# 12318         BONNIERES                     Amethyste        7
# 296689  CHAMP DE COURSE                 Autres titres       10
# 37739           VIARMES                     Imagine R       76

# %%
for fichier in fichiers:
    with fs.open(fichier, mode="rb") as fichier:
        donnees = pd.read_excel(fichier)
donnees.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 3
#       1 for fichier in fichiers:
#       2     with fs.open(fichier, mode="rb") as fichier:
# ----> 3         donnees = pd.read_excel(fichier)
#       4 donnees.head()
#
# File /opt/python/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /opt/python/lib/python3.13/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File /opt/python/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)    550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File /opt/python/lib/python3.13/site-packages/pandas/io/excel/_base.py:573, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     571 self.handles.handle.seek(0)
#     572 try:
# --> 573     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     574 except Exception:
#     575     self.close()
#
# File /opt/python/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:572, in OpenpyxlReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#     568 from openpyxl import load_workbook
#     570 default_kwargs = {"read_only": True, "data_only": True, "keep_links": False}
# --> 572 return load_workbook(
#     573     filepath_or_buffer,
#     574     **(default_kwargs | engine_kwargs),
#     575 )
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/reader/excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)    344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/reader/excel.py:303, in ExcelReader.read(self)
#     301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
# --> 303 self.read_worksheets()
#     304 action = "assign names"
#     305 self.parser.assign_names()
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/reader/excel.py:228, in ExcelReader.read_worksheets(self)
#     225     rels = get_dependents(self.archive, rels_path)
#     227 if self.read_only:
# --> 228     ws = ReadOnlyWorksheet(self.wb, sheet.name, rel.target, self.shared_strings)
#     229     ws.sheet_state = sheet.state
#     230     self.wb._sheets.append(ws)
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/worksheet/_read_only.py:42, in ReadOnlyWorksheet.__init__(self, parent_workbook, title, worksheet_path, shared_strings)
#      40 self._worksheet_path = worksheet_path
#      41 self._shared_strings = shared_strings
# ---> 42 self._get_size()
#      43 self.defined_names = DefinedNameDict()
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/worksheet/_read_only.py:49, in ReadOnlyWorksheet._get_size(self)
#      47 src = self._get_source()
#      48 parser = WorkSheetParser(src, [])
# ---> 49 dimensions = parser.parse_dimensions()
#      50 src.close()
#      51 if dimensions is not None:
#
# File /opt/python/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:178, in WorkSheetParser.parse_dimensions(self)
#     173 """
#     174 Get worksheet dimensions if they are provided.
#     175 """
#     176 it = iterparse(self.source)
# --> 178 for _event, element in it:
#     179     if element.tag == DIMENSION_TAG:
#     180         dim = SheetDimension.from_tree(element)
#
# File /opt/python/lib/python3.13/xml/etree/ElementTree.py:1247, in iterparse.<locals>.iterator(source)
#    1245     if not data:
#    1246         break
# -> 1247     pullparser.feed(data)
#    1248 root = pullparser._close_and_return_root()
#    1249 yield from pullparser.read_events()
#
# File /opt/python/lib/python3.13/xml/etree/ElementTree.py:1297, in XMLPullParser.feed(self, data)
#    1295 if data:
#    1296     try:
# -> 1297         self._parser.feed(data)
#    1298     except SyntaxError as exc:
#    1299         self._events_queue.append(exc)
#
# KeyboardInterrupt:

# %% [markdown]
# # Concaténation des quatre fichiers en un dataframe Pandas

# %% [markdown]
# donnees.tail()

# %% [markdown]
# donnees.dtypes
